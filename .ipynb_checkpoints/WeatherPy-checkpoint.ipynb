# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(cities)
# Out:
# ['barrow', 'gouyave', 'noumea', 'busselton', 'isangel', 'ushuaia', 'mahebourg', 'grand river south east', 'isla vista', 'saskylakh', 'jamestown', 'vardo', 'tsihombe', 'chuy', 'camacha', 'ambilobe', 'hermanus', 'lavrentiya', 'nanortalik', 'bredasdorp', 'chokurdakh', 'beringovskiy', 'kokopo', 'kihei', 'georgetown', 'jashpurnagar', 'avarua', 'alofi', 'arraial do cabo', 'taolanaro', 'klyuchi', 'cape town', 'taksimo', 'salinopolis', 'wukari', 'de aar', 'rikitea', 'mataura', 'kapaa', 'qaanaaq', 'markala', 'hilo', 'buchanan', 'alexandria', 'lagoa', 'barentsburg', 'tuatapere', 'butaritari', 'illoqqortoormiut', 'port alfred', 'awjilah', 'hokitika', 'albany', 'new norfolk', 'ribeira grande', 'savannah bight', 'dryden', 'attawapiskat', 'veriora', 'airai', 'baghdad', 'naze', 'ngukurr', 'hasaki', 'louisbourg', 'punta arenas', 'lahad datu', 'ahipara', 'mehamn', 'aflu', 'namibe', 'atar', 'pontianak', 'dikson', 'nikolskoye', 'galgani', 'fortuna', 'tiksi', 'ponta do sol', 'sao jose da coroa grande', 'cherskiy', 'muros', 'vagay', 'half moon bay', 'castro', 'kjollefjord', 'tidore', 'yarada', 'hobart', 'nizhneyansk', 'weligama', 'akureyri', 'atuona', 'gharghoda', 'klaksvik', 'tasiilaq', 'mahibadhoo', 'bluff', 'imbituba', 'navahrudak', 'carnarvon', 'east london', 'yangambi', 'hualmay', 'price', 'poum', 'chandbali', 'kavaratti', 'ngunguru', 'ventspils', 'vaitape', 'margate', 'yar-sale', 'mangrol', 'hithadhoo', 'asyut', 'berezovyy', 'umzimvubu', 'puerto ayora', 'vaini', 'vryburg', 'bathsheba', 'codrington', 'wonthaggi', 'tuktoyaktuk', 'ternate', 'upernavik', 'korla', 'pakruojis', 'hailar', 'port blair', 'yellowknife', 'moerai', 'christchurch', 'ahuimanu', 'samusu', 'broken hill', 'sinkat', 'colquechaca', 'thunder bay', 'oktyabrskoye', 'goderich', 'ballina', 'flin flon', 'krutinka', 'riyadh', 'kavieng', 'grindavik', 'port elizabeth', 'paranaiba', 'komsomolskiy', 'harper', 'shurugwi', 'dunedin', 'solnechnyy', 'karaul', 'ohara', 'vila velha', 'atambua', 'tonota', 'kangaatsiaq', 'laguna', 'hambantota', 'newport', 'den helder', 'bethel', 'kununurra', 'juneau', 'galle', 'eureka', 'bongouanou', 'concordia', 'morehead', 'sur', 'busembatia', 'safwah', 'victoria', 'anloga', 'rockland', 'torbay', 'athabasca', 'cidreira', 'chimore', 'atherton', 'mar del plata', 'pathalgaon', 'los llanos de aridane', 'kielce', 'manaus', 'lompoc', 'buala', 'smoky lake', 'prince rupert', 'sao filipe', 'tobol', 'solovetskiy', 'ruatoria', 'creston', 'nemuro', 'puqi', 'mandan', 'almenara', 'luderitz', 'bosaso', 'yining', 'manapparai', 'saint-philippe', 'qaqortoq', 'clyde river', 'tautira', 'kaeo', 'avera', 'nuuk', 'saleaula', 'atbasar', 'berlevag', 'ajuchitlan', 'gazojak', 'faanui', 'dawlatabad', 'quelimane', 'esperance', 'chunoyar', 'dwarka', 'kigoma', 'pevek', 'vaitupu', 'baykit', 'havre-saint-pierre', 'arman', 'barcelos', 'yerbogachen', 'bengkulu', 'hervey bay', 'porangatu', 'elk city', 'kodiak', 'namatanai', 'khilok', 'longyearbyen', 'sept-iles', 'waipawa', 'rock sound', 'avesta', 'shingu', 'saint george', 'palmer', 'geraldton', 'ruteng', 'richards bay', 'makhachkala', 'soure', 'labutta', 'porto novo', 'kawalu', 'srednekolymsk', 'dingle', 'alihe', 'carutapera', 'rocha', 'kloulklubed', 'pacific grove', 'guapore', 'warin chamrap', 'port moresby', 'alice springs', 'gayny', 'lorengau', 'cockburn town', 'hamilton', 'xichang', 'harlingen', 'whitehorse', 'meyungs', 'puerto escondido', 'egvekinot', 'sola', 'cyangugu', 'nangwa', 'khatanga', 'sambava', 'wenling', 'malakal', 'pangnirtung', 'palasbari', 'upington', 'luang prabang', 'fairbanks', 'petrovsk-zabaykalskiy', 'afgoye', 'gizo', 'brainerd', 'faya', 'ostrovnoy', 'viedma', 'lubango', 'velasco ibarra', 'haines junction', 'koshurnikovo', 'fevralsk', 'marawi', 'kaitangata', 'lubbock', 'coquimbo', 'jaciara', 'walvis bay', 'ambagarh chauki', 'klaeng', 'tazovskiy', 'fianga', 'kampong chhnang', 'gladstone', 'souillac', 'inuvik', 'dilla', 'jalu', 'ust-nera', 'carthage', 'san pedro', 'niono', 'belushya guba', 'lasa', 'flinders', 'norman wells', ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

of_set = 1
record = 0

city_list = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lon = []
max_temp = []
wind_speed = []

print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = f"{url}appid={api_key}&q={city}&units=Imperial"
    weather_response = requests.get(query_url).json()
    
    if record < 50:
        record += 1
    else:
        of_set += 1 
        record = 1
    
    print(f"Processing Record {record} of set {of_set} | {city}.")
    
    try:
        cloudiness.append(weather_response["clouds"]["all"])
        country.append(weather_response["sys"]["country"])
        date.append(weather_response["dt"])
        humidity.append(weather_response["main"]["humidity"])
        lat.append(weather_response["coord"]["lat"])
        lon.append(weather_response["coord"]["lon"])      
        max_temp.append(weather_response["main"]["temp_max"])
        wind_speed.append(weather_response["wind"]["speed"])
        city_list.append(city)

    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of set 1 | barrow.
# Processing Record 2 of set 1 | gouyave.
# Processing Record 3 of set 1 | noumea.
# Processing Record 4 of set 1 | busselton.
# Processing Record 5 of set 1 | isangel.
# Processing Record 6 of set 1 | ushuaia.
# Processing Record 7 of set 1 | mahebourg.
# Processing Record 8 of set 1 | grand river south east.
# Missing field/result... skipping.
# Processing Record 9 of set 1 | isla vista.
# Processing Record 10 of set 1 | saskylakh.
# Processing Record 11 of set 1 | jamestown.
# Processing Record 12 of set 1 | vardo.
# Processing Record 13 of set 1 | tsihombe.
# Missing field/result... skipping.
# Processing Record 14 of set 1 | chuy.
# Processing Record 15 of set 1 | camacha.
# Processing Record 16 of set 1 | ambilobe.
# Processing Record 17 of set 1 | hermanus.
# Processing Record 18 of set 1 | lavrentiya.
# Processing Record 19 of set 1 | nanortalik.
# Processing Record 20 of set 1 | bredasdorp.
# Processing Record 21 of set 1 | chokurdakh.
# Processing Record 22 of set 1 | beringovskiy.
# Processing Record 23 of set 1 | kokopo.
# Processing Record 24 of set 1 | kihei.
# Processing Record 25 of set 1 | georgetown.
# Processing Record 26 of set 1 | jashpurnagar.
# Processing Record 27 of set 1 | avarua.
# Processing Record 28 of set 1 | alofi.
# Processing Record 29 of set 1 | arraial do cabo.
# Processing Record 30 of set 1 | taolanaro.
# Missing field/result... skipping.
# Processing Record 31 of set 1 | klyuchi.
# Processing Record 32 of set 1 | cape town.
# Processing Record 33 of set 1 | taksimo.
# Processing Record 34 of set 1 | salinopolis.
# Processing Record 35 of set 1 | wukari.
# Processing Record 36 of set 1 | de aar.
# Processing Record 37 of set 1 | rikitea.
# Processing Record 38 of set 1 | mataura.
# Processing Record 39 of set 1 | kapaa.
# Processing Record 40 of set 1 | qaanaaq.
# Processing Record 41 of set 1 | markala.
# Processing Record 42 of set 1 | hilo.
# Processing Record 43 of set 1 | buchanan.
# Processing Record 44 of set 1 | alexandria.
# Processing Record 45 of set 1 | lagoa.
# Processing Record 46 of set 1 | barentsburg.
# Missing field/result... skipping.
# Processing Record 47 of set 1 | tuatapere.
# Processing Record 48 of set 1 | butaritari.
# Processing Record 49 of set 1 | illoqqortoormiut.
# Missing field/result... skipping.
# Processing Record 50 of set 1 | port alfred.
# Processing Record 1 of set 2 | awjilah.
# Processing Record 2 of set 2 | hokitika.
# Processing Record 3 of set 2 | albany.
# Processing Record 4 of set 2 | new norfolk.
# Processing Record 5 of set 2 | ribeira grande.
# Processing Record 6 of set 2 | savannah bight.
# Processing Record 7 of set 2 | dryden.
# Processing Record 8 of set 2 | attawapiskat.
# Missing field/result... skipping.
# Processing Record 9 of set 2 | veriora.
# Processing Record 10 of set 2 | airai.
# Processing Record 11 of set 2 | baghdad.
# Processing Record 12 of set 2 | naze.
# Processing Record 13 of set 2 | ngukurr.
# Missing field/result... skipping.
# Processing Record 14 of set 2 | hasaki.
# Processing Record 15 of set 2 | louisbourg.
# Missing field/result... skipping.
# Processing Record 16 of set 2 | punta arenas.
# Processing Record 17 of set 2 | lahad datu.
# Processing Record 18 of set 2 | ahipara.
# Processing Record 19 of set 2 | mehamn.
# Processing Record 20 of set 2 | aflu.
# Missing field/result... skipping.
# Processing Record 21 of set 2 | namibe.
# Processing Record 22 of set 2 | atar.
# Processing Record 23 of set 2 | pontianak.
# Processing Record 24 of set 2 | dikson.
# Processing Record 25 of set 2 | nikolskoye.
# Processing Record 26 of set 2 | galgani.
# Missing field/result... skipping.
# Processing Record 27 of set 2 | fortuna.
# Processing Record 28 of set 2 | tiksi.
# Processing Record 29 of set 2 | ponta do sol.
# Processing Record 30 of set 2 | sao jose da coroa grande.
# Processing Record 31 of set 2 | cherskiy.
# Processing Record 32 of set 2 | muros.
# Processing Record 33 of set 2 | vagay.
# Processing Record 34 of set 2 | half moon bay.
# Processing Record 35 of set 2 | castro.
# Processing Record 36 of set 2 | kjollefjord.
# Processing Record 37 of set 2 | tidore.
# Missing field/result... skipping.
# Processing Record 38 of set 2 | yarada.
# Processing Record 39 of set 2 | hobart.
# Processing Record 40 of set 2 | nizhneyansk.
# Missing field/result... skipping.
# Processing Record 41 of set 2 | weligama.
# Processing Record 42 of set 2 | akureyri.
# Processing Record 43 of set 2 | atuona.
# Processing Record 44 of set 2 | gharghoda.
# Processing Record 45 of set 2 | klaksvik.
# Processing Record 46 of set 2 | tasiilaq.
# Processing Record 47 of set 2 | mahibadhoo.
# Processing Record 48 of set 2 | bluff.
# Processing Record 49 of set 2 | imbituba.
# Processing Record 50 of set 2 | navahrudak.
# Processing Record 1 of set 3 | carnarvon.
# Processing Record 2 of set 3 | east london.
# Processing Record 3 of set 3 | yangambi.
# Processing Record 4 of set 3 | hualmay.
# Processing Record 5 of set 3 | price.
# Processing Record 6 of set 3 | poum.
# Processing Record 7 of set 3 | chandbali.
# Processing Record 8 of set 3 | kavaratti.
# Processing Record 9 of set 3 | ngunguru.
# Processing Record 10 of set 3 | ventspils.
# Processing Record 11 of set 3 | vaitape.
# Processing Record 12 of set 3 | margate.
# Processing Record 13 of set 3 | yar-sale.
# Processing Record 14 of set 3 | mangrol.
# Processing Record 15 of set 3 | hithadhoo.
# Processing Record 16 of set 3 | asyut.
# Processing Record 17 of set 3 | berezovyy.
# Processing Record 18 of set 3 | umzimvubu.
# Missing field/result... skipping.
# Processing Record 19 of set 3 | puerto ayora.
# Processing Record 20 of set 3 | vaini.
# Processing Record 21 of set 3 | vryburg.
# Processing Record 22 of set 3 | bathsheba.
# Processing Record 23 of set 3 | codrington.
# Processing Record 24 of set 3 | wonthaggi.
# Processing Record 25 of set 3 | tuktoyaktuk.
# Processing Record 26 of set 3 | ternate.
# Processing Record 27 of set 3 | upernavik.
# Processing Record 28 of set 3 | korla.
# Missing field/result... skipping.
# Processing Record 29 of set 3 | pakruojis.
# Processing Record 30 of set 3 | hailar.
# Processing Record 31 of set 3 | port blair.
# Processing Record 32 of set 3 | yellowknife.
# Processing Record 33 of set 3 | moerai.
# Processing Record 34 of set 3 | christchurch.
# Processing Record 35 of set 3 | ahuimanu.
# Processing Record 36 of set 3 | samusu.
# Missing field/result... skipping.
# Processing Record 37 of set 3 | broken hill.
# Processing Record 38 of set 3 | sinkat.
# Missing field/result... skipping.
# Processing Record 39 of set 3 | colquechaca.
# Processing Record 40 of set 3 | thunder bay.
# Processing Record 41 of set 3 | oktyabrskoye.
# Processing Record 42 of set 3 | goderich.
# Processing Record 43 of set 3 | ballina.
# Processing Record 44 of set 3 | flin flon.
# Processing Record 45 of set 3 | krutinka.
# Processing Record 46 of set 3 | riyadh.
# Processing Record 47 of set 3 | kavieng.
# Processing Record 48 of set 3 | grindavik.
# Processing Record 49 of set 3 | port elizabeth.
# Processing Record 50 of set 3 | paranaiba.
# Processing Record 1 of set 4 | komsomolskiy.
# Processing Record 2 of set 4 | harper.
# Processing Record 3 of set 4 | shurugwi.
# Processing Record 4 of set 4 | dunedin.
# Processing Record 5 of set 4 | solnechnyy.
# Processing Record 6 of set 4 | karaul.
# Missing field/result... skipping.
# Processing Record 7 of set 4 | ohara.
# Processing Record 8 of set 4 | vila velha.
# Processing Record 9 of set 4 | atambua.
# Processing Record 10 of set 4 | tonota.
# Processing Record 11 of set 4 | kangaatsiaq.
# Processing Record 12 of set 4 | laguna.
# Processing Record 13 of set 4 | hambantota.
# Processing Record 14 of set 4 | newport.
# Processing Record 15 of set 4 | den helder.
# Processing Record 16 of set 4 | bethel.
# Processing Record 17 of set 4 | kununurra.
# Processing Record 18 of set 4 | juneau.
# Processing Record 19 of set 4 | galle.
# Processing Record 20 of set 4 | eureka.
# Processing Record 21 of set 4 | bongouanou.
# Processing Record 22 of set 4 | concordia.
# Processing Record 23 of set 4 | morehead.
# Processing Record 24 of set 4 | sur.
# Processing Record 25 of set 4 | busembatia.
# Processing Record 26 of set 4 | safwah.
# Missing field/result... skipping.
# Processing Record 27 of set 4 | victoria.
# Processing Record 28 of set 4 | anloga.
# Processing Record 29 of set 4 | rockland.
# Processing Record 30 of set 4 | torbay.
# Processing Record 31 of set 4 | athabasca.
# Processing Record 32 of set 4 | cidreira.
# Processing Record 33 of set 4 | chimore.
# Processing Record 34 of set 4 | atherton.
# Processing Record 35 of set 4 | mar del plata.
# Processing Record 36 of set 4 | pathalgaon.
# Processing Record 37 of set 4 | los llanos de aridane.
# Processing Record 38 of set 4 | kielce.
# Processing Record 39 of set 4 | manaus.
# Processing Record 40 of set 4 | lompoc.
# Processing Record 41 of set 4 | buala.
# Processing Record 42 of set 4 | smoky lake.
# Processing Record 43 of set 4 | prince rupert.
# Processing Record 44 of set 4 | sao filipe.
# Processing Record 45 of set 4 | tobol.
# Processing Record 46 of set 4 | solovetskiy.
# Missing field/result... skipping.
# Processing Record 47 of set 4 | ruatoria.
# Missing field/result... skipping.
# Processing Record 48 of set 4 | creston.
# Processing Record 49 of set 4 | nemuro.
# Processing Record 50 of set 4 | puqi.
# Processing Record 1 of set 5 | mandan.
# Processing Record 2 of set 5 | almenara.
# Processing Record 3 of set 5 | luderitz.
# Processing Record 4 of set 5 | bosaso.
# Processing Record 5 of set 5 | yining.
# Processing Record 6 of set 5 | manapparai.
# Processing Record 7 of set 5 | saint-philippe.
# Processing Record 8 of set 5 | qaqortoq.
# Processing Record 9 of set 5 | clyde river.
# Processing Record 10 of set 5 | tautira.
# Processing Record 11 of set 5 | kaeo.
# Processing Record 12 of set 5 | avera.
# Processing Record 13 of set 5 | nuuk.
# Processing Record 14 of set 5 | saleaula.
# Missing field/result... skipping.
# Processing Record 15 of set 5 | atbasar.
# Processing Record 16 of set 5 | berlevag.
# Processing Record 17 of set 5 | ajuchitlan.
# Processing Record 18 of set 5 | gazojak.
# Processing Record 19 of set 5 | faanui.
# Processing Record 20 of set 5 | dawlatabad.
# Processing Record 21 of set 5 | quelimane.
# Processing Record 22 of set 5 | esperance.
# Processing Record 23 of set 5 | chunoyar.
# Processing Record 24 of set 5 | dwarka.
# Processing Record 25 of set 5 | kigoma.
# Processing Record 26 of set 5 | pevek.
# Processing Record 27 of set 5 | vaitupu.
# Missing field/result... skipping.
# Processing Record 28 of set 5 | baykit.
# Processing Record 29 of set 5 | havre-saint-pierre.
# Processing Record 30 of set 5 | arman.
# Processing Record 31 of set 5 | barcelos.
# Processing Record 32 of set 5 | yerbogachen.
# Processing Record 33 of set 5 | bengkulu.
# Missing field/result... skipping.
# Processing Record 34 of set 5 | hervey bay.
# Processing Record 35 of set 5 | porangatu.
# Processing Record 36 of set 5 | elk city.
# Processing Record 37 of set 5 | kodiak.
# Processing Record 38 of set 5 | namatanai.
# Processing Record 39 of set 5 | khilok.
# Processing Record 40 of set 5 | longyearbyen.
# Processing Record 41 of set 5 | sept-iles.
# Processing Record 42 of set 5 | waipawa.
# Processing Record 43 of set 5 | rock sound.
# Processing Record 44 of set 5 | avesta.
# Processing Record 45 of set 5 | shingu.
# Processing Record 46 of set 5 | saint george.
# Processing Record 47 of set 5 | palmer.
# Processing Record 48 of set 5 | geraldton.
# Processing Record 49 of set 5 | ruteng.
# Processing Record 50 of set 5 | richards bay.
# Processing Record 1 of set 6 | makhachkala.
# Processing Record 2 of set 6 | soure.
# Processing Record 3 of set 6 | labutta.
# Missing field/result... skipping.
# Processing Record 4 of set 6 | porto novo.
# Processing Record 5 of set 6 | kawalu.
# Processing Record 6 of set 6 | srednekolymsk.
# Processing Record 7 of set 6 | dingle.
# Processing Record 8 of set 6 | alihe.
# Processing Record 9 of set 6 | carutapera.
# Processing Record 10 of set 6 | rocha.
# Processing Record 11 of set 6 | kloulklubed.
# Processing Record 12 of set 6 | pacific grove.
# Processing Record 13 of set 6 | guapore.
# Missing field/result... skipping.
# Processing Record 14 of set 6 | warin chamrap.
# Processing Record 15 of set 6 | port moresby.
# Processing Record 16 of set 6 | alice springs.
# Processing Record 17 of set 6 | gayny.
# Processing Record 18 of set 6 | lorengau.
# Processing Record 19 of set 6 | cockburn town.
# Processing Record 20 of set 6 | hamilton.
# Processing Record 21 of set 6 | xichang.
# Processing Record 22 of set 6 | harlingen.
# Processing Record 23 of set 6 | whitehorse.
# Processing Record 24 of set 6 | meyungs.
# Missing field/result... skipping.
# Processing Record 25 of set 6 | puerto escondido.
# Processing Record 26 of set 6 | egvekinot.
# Processing Record 27 of set 6 | sola.
# Processing Record 28 of set 6 | cyangugu.
# Processing Record 29 of set 6 | nangwa.
# Processing Record 30 of set 6 | khatanga.
# Processing Record 31 of set 6 | sambava.
# Processing Record 32 of set 6 | wenling.
# Processing Record 33 of set 6 | malakal.
# Missing field/result... skipping.
# Processing Record 34 of set 6 | pangnirtung.
# Processing Record 35 of set 6 | palasbari.
# Processing Record 36 of set 6 | upington.
# Processing Record 37 of set 6 | luang prabang.
# Processing Record 38 of set 6 | fairbanks.
# Processing Record 39 of set 6 | petrovsk-zabaykalskiy.
# Processing Record 40 of set 6 | afgoye.
# Missing field/result... skipping.
# Processing Record 41 of set 6 | gizo.
# Processing Record 42 of set 6 | brainerd.
# Processing Record 43 of set 6 | faya.
# Processing Record 44 of set 6 | ostrovnoy.
# Processing Record 45 of set 6 | viedma.
# Processing Record 46 of set 6 | lubango.
# Processing Record 47 of set 6 | velasco ibarra.
# Processing Record 48 of set 6 | haines junction.
# Processing Record 49 of set 6 | koshurnikovo.
# Processing Record 50 of set 6 | fevralsk.
# Missing field/result... skipping.
# Processing Record 1 of set 7 | marawi.
# Processing Record 2 of set 7 | kaitangata.
# Processing Record 3 of set 7 | lubbock.
# Processing Record 4 of set 7 | coquimbo.
# Processing Record 5 of set 7 | jaciara.
# Processing Record 6 of set 7 | walvis bay.
# Processing Record 7 of set 7 | ambagarh chauki.
# Processing Record 8 of set 7 | klaeng.
# Processing Record 9 of set 7 | tazovskiy.
# Processing Record 10 of set 7 | fianga.
# Missing field/result... skipping.
# Processing Record 11 of set 7 | kampong chhnang.
# Processing Record 12 of set 7 | gladstone.
# Processing Record 13 of set 7 | souillac.
# Processing Record 14 of set 7 | inuvik.
# Processing Record 15 of set 7 | dilla.
# Processing Record 16 of set 7 | jalu.
# Processing Record 17 of set 7 | ust-nera.
# Processing Record 18 of set 7 | carthage.
# Processing Record 19 of set 7 | san pedro.
# Processing Record 20 of set 7 | niono.
# Processing Record 21 of set 7 | belushya guba.
# Missing field/result... skipping.
# Processing Record 22 of set 7 | lasa.
# Processing Record 23 of set 7 | flinders.
# Processing Record 24 of set 7 | norman wells.
# Processing Record 25 of set 7 | cabo san lucas.
# Processing Record 26 of set 7 | sitka.
# Processing Record 27 of set 7 | antofagasta.
# Processing Record 28 of set 7 | vila franca do campo.
# Processing Record 29 of set 7 | kon tum.
# Processing Record 30 of set 7 | mys shmidta.
# Missing field/result... skipping.
# Processing Record 31 of set 7 | tornio.
# Processing Record 32 of set 7 | sedalia.
# Processing Record 33 of set 7 | na wa.
# Processing Record 34 of set 7 | fort nelson.
# Processing Record 35 of set 7 | marcona.
# Missing field/result... skipping.
# Processing Record 36 of set 7 | mattawa.
# Processing Record 37 of set 7 | sinegorye.
# Processing Record 38 of set 7 | san vicente.
# Processing Record 39 of set 7 | labuhan.
# Processing Record 40 of set 7 | cabedelo.
# Processing Record 41 of set 7 | uwayl.
# Missing field/result... skipping.
# Processing Record 42 of set 7 | samarai.
# Processing Record 43 of set 7 | gweta.
# Processing Record 44 of set 7 | port-gentil.
# Processing Record 45 of set 7 | qandahar.
# Missing field/result... skipping.
# Processing Record 46 of set 7 | aksarka.
# Processing Record 47 of set 7 | dzhebariki-khaya.
# Processing Record 48 of set 7 | constitucion.
# Processing Record 49 of set 7 | mugumu.
# Processing Record 50 of set 7 | ayan.
# Processing Record 1 of set 8 | san bartolome de tirajana.
# Missing field/result... skipping.
# Processing Record 2 of set 8 | vung tau.
# Processing Record 3 of set 8 | bakloh.
# Processing Record 4 of set 8 | burns lake.
# Processing Record 5 of set 8 | bereda.
# Processing Record 6 of set 8 | san patricio.
# Processing Record 7 of set 8 | okhotsk.
# Processing Record 8 of set 8 | dakar.
# Processing Record 9 of set 8 | nanchang.
# Processing Record 10 of set 8 | nawalgarh.
# Processing Record 11 of set 8 | nagato.
# Processing Record 12 of set 8 | mount gambier.
# Processing Record 13 of set 8 | coihaique.
# Processing Record 14 of set 8 | acolla.
# Processing Record 15 of set 8 | kargopol.
# Processing Record 16 of set 8 | tourlaville.
# Processing Record 17 of set 8 | avrille.
# Processing Record 18 of set 8 | yulara.
# Processing Record 19 of set 8 | tifton.
# Processing Record 20 of set 8 | kargasok.
# Processing Record 21 of set 8 | moron.
# Processing Record 22 of set 8 | acheng.
# Processing Record 23 of set 8 | arlit.
# Processing Record 24 of set 8 | yuxia.
# Processing Record 25 of set 8 | san quintin.
# Processing Record 26 of set 8 | narsaq.
# Processing Record 27 of set 8 | ankara.
# Processing Record 28 of set 8 | haicheng.
# Processing Record 29 of set 8 | changde.
# Processing Record 30 of set 8 | kenai.
# Processing Record 31 of set 8 | usinsk.
# Processing Record 32 of set 8 | omsukchan.
# Processing Record 33 of set 8 | thompson.
# Processing Record 34 of set 8 | trelew.
# Processing Record 35 of set 8 | sakakah.
# Missing field/result... skipping.
# Processing Record 36 of set 8 | srivardhan.
# Processing Record 37 of set 8 | jieshi.
# Processing Record 38 of set 8 | beyneu.
# Processing Record 39 of set 8 | letlhakane.
# Processing Record 40 of set 8 | la serena.
# Processing Record 41 of set 8 | praya.
# Processing Record 42 of set 8 | ihosy.
# Processing Record 43 of set 8 | asau.
# Missing field/result... skipping.
# Processing Record 44 of set 8 | auch.
# Processing Record 45 of set 8 | kirakira.
# Processing Record 46 of set 8 | lata.
# Processing Record 47 of set 8 | guerrero negro.
# Processing Record 48 of set 8 | kintampo.
# Processing Record 49 of set 8 | tateyama.
# Processing Record 50 of set 8 | provideniya.
# Processing Record 1 of set 9 | kargat.
# Processing Record 2 of set 9 | ayios kirikos.
# Missing field/result... skipping.
# Processing Record 3 of set 9 | iqaluit.
# Processing Record 4 of set 9 | lebu.
# Processing Record 5 of set 9 | tumannyy.
# Missing field/result... skipping.
# Processing Record 6 of set 9 | abu dhabi.
# Processing Record 7 of set 9 | sorland.
# Processing Record 8 of set 9 | halifax.
# Processing Record 9 of set 9 | ratnagiri.
# Processing Record 10 of set 9 | gannan.
# Processing Record 11 of set 9 | saravan.
# Processing Record 12 of set 9 | zeya.
# Processing Record 13 of set 9 | saldanha.
# Processing Record 14 of set 9 | palabuhanratu.
# Missing field/result... skipping.
# Processing Record 15 of set 9 | luganville.
# Processing Record 16 of set 9 | itoman.
# Processing Record 17 of set 9 | kuytun.
# Processing Record 18 of set 9 | paamiut.
# Processing Record 19 of set 9 | gold coast.
# Processing Record 20 of set 9 | itabirito.
# Processing Record 21 of set 9 | beloha.
# Processing Record 22 of set 9 | biltine.
# Processing Record 23 of set 9 | bubaque.
# Processing Record 24 of set 9 | luangwa.
# Processing Record 25 of set 9 | north bend.
# Processing Record 26 of set 9 | sabha.
# Processing Record 27 of set 9 | vanatori.
# Processing Record 28 of set 9 | ilembo.
# Processing Record 29 of set 9 | dalvik.
# Processing Record 30 of set 9 | aykhal.
# Processing Record 31 of set 9 | tual.
# Processing Record 32 of set 9 | zhaoyang.
# Processing Record 33 of set 9 | nishihara.
# Processing Record 34 of set 9 | raga.
# Missing field/result... skipping.
# Processing Record 35 of set 9 | mosquera.
# Processing Record 36 of set 9 | pepel.
# Processing Record 37 of set 9 | itarantim.
# Processing Record 38 of set 9 | bilibino.
# Processing Record 39 of set 9 | ouadda.
# Processing Record 40 of set 9 | mayskiy.
# Processing Record 41 of set 9 | poya.
# Processing Record 42 of set 9 | kaohsiung.
# Processing Record 43 of set 9 | pamekasan.
# Processing Record 44 of set 9 | kirkwall.
# Processing Record 45 of set 9 | xingyi.
# Processing Record 46 of set 9 | micheweni.
# Processing Record 47 of set 9 | vangaindrano.
# Processing Record 48 of set 9 | aktash.
# Missing field/result... skipping.
# Processing Record 49 of set 9 | qasigiannguit.
# Processing Record 50 of set 9 | severo-kurilsk.
# Processing Record 1 of set 10 | ponta delgada.
# Processing Record 2 of set 10 | ust-kuyga.
# Processing Record 3 of set 10 | mao.
# Processing Record 4 of set 10 | qeshm.
# Processing Record 5 of set 10 | saint-francois.
# Processing Record 6 of set 10 | wanning.
# Processing Record 7 of set 10 | nome.
# Processing Record 8 of set 10 | santa maria.
# Processing Record 9 of set 10 | aklavik.
# Processing Record 10 of set 10 | kuopio.
# Processing Record 11 of set 10 | gollere.
# Missing field/result... skipping.
# Processing Record 12 of set 10 | saint-augustin.
# Processing Record 13 of set 10 | geresk.
# Missing field/result... skipping.
# Processing Record 14 of set 10 | oktyabrskiy.
# Processing Record 15 of set 10 | zheleznodorozhnyy.
# Processing Record 16 of set 10 | pokhara.
# Processing Record 17 of set 10 | young.
# Processing Record 18 of set 10 | caravelas.
# Processing Record 19 of set 10 | bolshiye uki.
# Missing field/result... skipping.
# Processing Record 20 of set 10 | camp verde.
# Processing Record 21 of set 10 | general bravo.
# Processing Record 22 of set 10 | jhelum.
# Processing Record 23 of set 10 | muzaffarpur.
# Processing Record 24 of set 10 | port-cartier.
# Processing Record 25 of set 10 | husavik.
# Processing Record 26 of set 10 | turukhansk.
# Processing Record 27 of set 10 | kungurtug.
# Processing Record 28 of set 10 | chabahar.
# Processing Record 29 of set 10 | zelenikovo.
# Processing Record 30 of set 10 | tommot.
# Processing Record 31 of set 10 | spencer.
# Processing Record 32 of set 10 | krasnoselkup.
# Missing field/result... skipping.
# Processing Record 33 of set 10 | dragoman.
# Processing Record 34 of set 10 | tongzi.
# Processing Record 35 of set 10 | muscat.
# Processing Record 36 of set 10 | charters towers.
# Processing Record 37 of set 10 | westport.
# Processing Record 38 of set 10 | kattivakkam.
# Processing Record 39 of set 10 | inhambane.
# Processing Record 40 of set 10 | leningradskiy.
# Processing Record 41 of set 10 | itarema.
# Processing Record 42 of set 10 | toliary.
# Missing field/result... skipping.
# Processing Record 43 of set 10 | karpathos.
# Processing Record 44 of set 10 | chicama.
# Processing Record 45 of set 10 | jinka.
# Processing Record 46 of set 10 | sentyabrskiy.
# Missing field/result... skipping.
# Processing Record 47 of set 10 | surami.
# Processing Record 48 of set 10 | fuxin.
# Processing Record 49 of set 10 | nara.
# Processing Record 50 of set 10 | le vauclin.
# Processing Record 1 of set 11 | ilhabela.
# Processing Record 2 of set 11 | krasnoarmeysk.
# Processing Record 3 of set 11 | piacabucu.
# Processing Record 4 of set 11 | tabou.
# Processing Record 5 of set 11 | barreirinhas.
# Processing Record 6 of set 11 | tutoia.
# Processing Record 7 of set 11 | saryshagan.
# Missing field/result... skipping.
# Processing Record 8 of set 11 | pisco.
# Processing Record 9 of set 11 | amderma.
# Missing field/result... skipping.
# Processing Record 10 of set 11 | alotau.
# Missing field/result... skipping.
# Processing Record 11 of set 11 | taywarah.
# Processing Record 12 of set 11 | sakaiminato.
# Processing Record 13 of set 11 | mlowo.
# Processing Record 14 of set 11 | katsuura.
# Processing Record 15 of set 11 | rawson.
# Processing Record 16 of set 11 | ucluelet.
# Processing Record 17 of set 11 | balsas.
# Processing Record 18 of set 11 | mirpur mathelo.
# Processing Record 19 of set 11 | dutlwe.
# Processing Record 20 of set 11 | rengasdengklok.
# Processing Record 21 of set 11 | okato.
# Processing Record 22 of set 11 | zhangye.
# Processing Record 23 of set 11 | oshkosh.
# Processing Record 24 of set 11 | lokosovo.
# Processing Record 25 of set 11 | smidovich.
# Processing Record 26 of set 11 | vignola.
# Processing Record 27 of set 11 | puerto del rosario.
# Processing Record 28 of set 11 | port lincoln.
# Processing Record 29 of set 11 | dum duma.
# Processing Record 30 of set 11 | bull savanna.
# Processing Record 31 of set 11 | leshukonskoye.
# Processing Record 32 of set 11 | rio gallegos.
# Processing Record 33 of set 11 | tubuala.
# Processing Record 34 of set 11 | coahuayana.
# Processing Record 35 of set 11 | port hedland.
# Processing Record 36 of set 11 | hirara.
# Processing Record 37 of set 11 | bethanien.
# Processing Record 38 of set 11 | mackay.
# Processing Record 39 of set 11 | vanimo.
# Processing Record 40 of set 11 | tromso.
# Processing Record 41 of set 11 | nouadhibou.
# Processing Record 42 of set 11 | tabas.
# Processing Record 43 of set 11 | yankton.
# Processing Record 44 of set 11 | northam.
# Processing Record 45 of set 11 | thinadhoo.
# Processing Record 46 of set 11 | chute-aux-outardes.
# Processing Record 47 of set 11 | kawana waters.
# Missing field/result... skipping.
# Processing Record 48 of set 11 | andros town.
# Processing Record 49 of set 11 | wahran.
# Missing field/result... skipping.
# Processing Record 50 of set 11 | sabang.
# Processing Record 1 of set 12 | tres lagoas.
# Missing field/result... skipping.
# Processing Record 2 of set 12 | himatangi.
# Processing Record 3 of set 12 | cairns.
# Processing Record 4 of set 12 | parkes.
# Processing Record 5 of set 12 | san policarpo.
# Processing Record 6 of set 12 | adrar.
# Processing Record 7 of set 12 | phalodi.
# Processing Record 8 of set 12 | kara-tyube.
# Processing Record 9 of set 12 | huarmey.
# Processing Record 10 of set 12 | pouebo.
# Processing Record 11 of set 12 | luwuk.
# Processing Record 12 of set 12 | kovur.
# Processing Record 13 of set 12 | cumaribo.
# Missing field/result... skipping.
# Processing Record 14 of set 12 | nakuru.
# Processing Record 15 of set 12 | poyarkovo.
# Processing Record 16 of set 12 | piskivka.
# Processing Record 17 of set 12 | olinda.
# Processing Record 18 of set 12 | seydi.
# Processing Record 19 of set 12 | urumqi.
# Missing field/result... skipping.
# Processing Record 20 of set 12 | maniitsoq.
# Processing Record 21 of set 12 | bac lieu.
# Missing field/result... skipping.
# Processing Record 22 of set 12 | chaman.
# Processing Record 23 of set 12 | russkoye.
# Processing Record 24 of set 12 | suez.
# Processing Record 25 of set 12 | juan aldama.
# Processing Record 26 of set 12 | shache.
# Processing Record 27 of set 12 | otjimbingwe.
# Processing Record 28 of set 12 | oderzo.
# Processing Record 29 of set 12 | impfondo.
# Processing Record 30 of set 12 | omboue.
# Processing Record 31 of set 12 | terny.
# Processing Record 32 of set 12 | ordzhonikidze.
# Processing Record 33 of set 12 | puerto ayacucho.
# Processing Record 34 of set 12 | sibolga.
# Processing Record 35 of set 12 | skovorodino.
# Processing Record 36 of set 12 | iralaya.
# Processing Record 37 of set 12 | kupang.
# Processing Record 38 of set 12 | fountain hills.
# Processing Record 39 of set 12 | teguise.
# Processing Record 40 of set 12 | nybro.
# Processing Record 41 of set 12 | severo-yeniseyskiy.
# Processing Record 42 of set 12 | bowen.
# Processing Record 43 of set 12 | tambun.
# Processing Record 44 of set 12 | mayo.
# Processing Record 45 of set 12 | grand gaube.
# Processing Record 46 of set 12 | shaikhpura.
# Processing Record 47 of set 12 | praia.
# Processing Record 48 of set 12 | svetlaya.
# Processing Record 49 of set 12 | bend.
# Processing Record 50 of set 12 | shenzhen.
# Processing Record 1 of set 13 | salalah.
# Processing Record 2 of set 13 | vao.
# Processing Record 3 of set 13 | goure.
# Processing Record 4 of set 13 | charagua.
# Processing Record 5 of set 13 | mikhaylovka.
# Processing Record 6 of set 13 | praia da vitoria.
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
#
# * Display the DataFrame

# %%
#Converting to dataframe
weather_df = pd.DataFrame({
    "City":city_list,
    "Cloudiness":cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Lon":lon,
    "Max Temp":max_temp,
    "Wind Speed":wind_speed
})

#Printing Counts
weather_df.count()
# Out:
# City          548
# Cloudiness    548
# Country       548
# Date          548
# Humidity      548
# Lat           548
# Lon           548
# Max Temp      548
# Wind Speed    548
# dtype: int64

# %%
weather_df.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0     barrow           0      AR  1572922736        66 -38.31  -60.23
# 1    gouyave          20      GD  1572922736        83  12.16  -61.73
# 2     noumea          75      NC  1572922736        40 -22.28  166.46
# 3  busselton          97      AU  1572922737        45 -33.64  115.35
# 4    isangel          75      VU  1572922709        48 -19.55  169.27
#
#    Max Temp  Wind Speed
# 0     45.57        4.27
# 1     82.40       10.29
# 2     89.60       12.75
# 3     72.00        8.61
# 4     84.20       13.87

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Plot Titles (with date of analysis) and Axes Labels.
fig, ax = plt.subplots()
plt.scatter(x=lat, y=max_temp, marker = "o", color="DarkBlue", alpha=0.5)
plt.title('City Latitude vs. Max Temp (11/4/2019)')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
ax.grid()
plt.show()
plt.savefig('City Latitude vs. Max Temp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Plot Titles (with date of analysis) and Axes Labels.
fig, ax = plt.subplots()
plt.scatter(x=lat, y=humidity, marker = "o", color="DarkBlue", alpha=0.5)
plt.title('City Latitude vs. Humidity (11/4/2019)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid = True
ax.grid()
plt.show()
plt.savefig('City Latitude vs. Humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Plot Titles (with date of analysis) and Axes Labels.
fig, ax = plt.subplots()
plt.scatter(x=lat, y=cloudiness, marker = "o", color="DarkBlue", alpha=0.5)
plt.title('City Latitude vs. Cloudiness (11/4/2019)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid = True
ax.grid()
plt.show()
plt.savefig('City Latitude vs. Cloudiness.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Plot Titles (with date of analysis) and Axes Labels.
fig, ax = plt.subplots()
plt.scatter(x=lat, y=wind_speed, marker = "o", color="DarkBlue", alpha=0.5)
plt.title('City Latitude vs. Wind Speed (11/4/2019)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.grid = True
ax.grid()
plt.show()
plt.savefig('City Latitude vs. Wind Speed.png')
