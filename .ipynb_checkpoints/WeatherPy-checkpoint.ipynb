# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
import csv

import datetime
d = datetime.datetime.today()
today = (f"{d.year}/{d.month}/{d.day}")

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(cities)
# Out:
# ['hobart', 'fairbanks', 'butaritari', 'busselton', 'taolanaro', 'victoria', 'sorland', 'poum', 'juneau', 'albany', 'nikita', 'lavrentiya', 'mahebourg', 'codrington', 'airai', 'mount isa', 'hermanus', 'dikson', 'norman wells', 'buri', 'cape town', 'aktau', 'tiznit', 'yellowknife', 'saint-philippe', 'riyadh', 'caravelas', 'mataura', 'ostrovnoy', 'mar del plata', 'peniche', 'bluff', 'new norfolk', 'puerto ayora', 'punta arenas', 'tiksi', 'chernyshevskiy', 'key west', 'ushuaia', 'upernavik', 'tecoanapa', 'quatre cocos', 'isfara', 'amapa', 'guilin', 'san quintin', 'arraial do cabo', 'lebu', 'rikitea', 'aktash', 'lakes entrance', 'karpathos', 'oranjestad', 'bredasdorp', 'khani', 'cidreira', 'hami', 'salalah', 'ahipara', 'gatesville', 'nome', 'sisimiut', 'tzaneen', 'moron', 'huntsville', 'kapaa', 'kodiak', 'nelson bay', 'sola', 'vestmannaeyjar', 'shingu', 'vaini', 'port alfred', 'chibuto', 'deputatskiy', 'dekar', 'chokurdakh', 'barrow', 'ribeira grande', 'la ronge', 'te anau', 'pisco', 'clyde river', 'aswan', 'hofn', 'urusha', 'jamestown', 'avera', 'galesong', 'east london', 'bandarbeyla', 'baicheng', 'abapo', 'urucara', 'myitkyina', 'prince rupert', 'chuy', 'banjar', 'alihe', 'ballina', 'illoqqortoormiut', 'sitka', 'bathsheba', 'nantucket', 'thompson', 'port-cartier', 'gorodets', 'sentyabrskiy', 'sergeyevka', 'kapoeta', 'comodoro rivadavia', 'hasaki', 'sayyan', 'sangar', 'san pedro buenavista', 'port lincoln', 'kaspiysk', 'saint george', 'sal rei', 'kathu', 'katsuura', 'lompoc', 'faanui', 'souillac', 'ca mau', 'sagua la grande', 'mys shmidta', 'sao filipe', 'santiago del estero', 'umzimvubu', 'bambanglipuro', 'oron', 'port hedland', 'khatanga', 'puerto del rosario', 'brooks', 'curvelo', 'pevek', 'hithadhoo', 'bethel', 'sao joao da barra', 'nuqui', 'mucurapo', 'nalut', 'kruisfontein', 'sao francisco de assis', 'tsihombe', 'talbahat', 'tessalit', 'novyy urengoy', 'hilo', 'ponta delgada', 'severo-kurilsk', 'torbay', 'port elizabeth', 'hemet', 'qaanaaq', 'muros', 'luderitz', 'kavieng', 'baudh', 'zyryanka', 'placido de castro', 'qeshm', 'alice springs', 'puerto cabello', 'palabuhanratu', 'pathein', 'maldonado', 'zhigansk', 'sambava', 'uchaly', 'haines junction', 'padang', 'georgetown', 'saldanha', 'cabo san lucas', 'nikolskoye', 'noumea', 'akureyri', 'saint-pierre', 'dali', 'castro', 'fort nelson', 'baykit', 'chikoy', 'flin flon', 'carnarvon', 'sept-iles', 'pyaozerskiy', 'san andres', 'urengoy', 'provideniya', 'hihifo', 'ponta do sol', 'monte gordo', 'gweta', 'along', 'alofi', 'rovaniemi', 'taoudenni', 'ihosy', 'longyearbyen', 'bac lieu', 'galveston', 'muhos', 'fort saint james', 'camocim', 'mentok', 'saleaula', 'gerash', 'atuona', 'maragogi', 'sulangan', 'san onofre', 'jiwani', 'contai', 'ixtapa', 'kungurtug', 'camabatela', 'bridgetown', 'tasiilaq', 'qom', 'belushya guba', 'abong mbang', 'samusu', 'turukhansk', 'eidsvag', 'tura', 'sarakhs', 'lerik', 'taga dzong', 'toliary', 'ipixuna', 'san patricio', 'giulianova', 'amiens', 'nuuk', 'shunyi', 'puerto escondido', 'paracuru', 'saint-denis', 'nikolayevka', 'viedma', 'mercedes', 'hoquiam', 'sumter', 'naze', 'aranda de duero', 'lakhimpur', 'mecca', 'faya', 'novaya lyada', 'fortuna foothills', 'balikpapan', 'pokhara', 'grand baie', 'lata', 'san cristobal', 'palmer', 'jarjis', 'barentsburg', 'vila velha', 'cherskiy', 'hudson bay', 'hay river', 'san policarpo', 'sebring', 'mount gambier', 'nanortalik', 'sarretudvari', 'sistranda', 'cradock', 'nizhneyansk', 'seoul', 'amderma', 'uzhur', 'maniitsoq', 'talikota', 'takab', 'klaksvik', 'kaitangata', 'honiara', 'tuktoyaktuk', 'killybegs', 'zonguldak', 'isangel', 'nyimba', 'thunder bay', 'shitkino', 'gat', 'port blair', 'bereda', 'kavaratti', 'mabaruma', 'verkhniy uslon', 'port shepstone', 'ouallam', 'zeya', 'nabire', 'kaeo', 'kamenka', 'rocha', 'lagoa', 'abu samrah', 'licata', 'shenjiamen', 'wladyslawowo', 'tambura', 'evensk', 'tommot', 'wattegama', 'araci', 'ancud', 'muravlenko', 'ayr', 'galiwinku', 'vaitupu', 'alekseyevka', 'talnakh', 'mackenzie', 'm ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

of_set = 1
record = 0

city_list = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lon = []
max_temp = []
wind_speed = []

print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = f"{url}appid={api_key}&q={city}&units=Imperial"
    weather_response = requests.get(query_url).json()
    
    if record < 50:
        record += 1
    else:
        of_set += 1 
        record = 1
    
    print(f"Processing Record {record} of set {of_set} | {city}.")
    
    try:
        cloudiness.append(weather_response["clouds"]["all"])
        country.append(weather_response["sys"]["country"])
        date.append(weather_response["dt"])
        humidity.append(weather_response["main"]["humidity"])
        lat.append(weather_response["coord"]["lat"])
        lon.append(weather_response["coord"]["lon"])      
        max_temp.append(weather_response["main"]["temp_max"])
        wind_speed.append(weather_response["wind"]["speed"])
        city_list.append(city)

    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of set 1 | hobart.
# Processing Record 2 of set 1 | fairbanks.
# Processing Record 3 of set 1 | butaritari.
# Processing Record 4 of set 1 | busselton.
# Processing Record 5 of set 1 | taolanaro.
# Missing field/result... skipping.
# Processing Record 6 of set 1 | victoria.
# Processing Record 7 of set 1 | sorland.
# Processing Record 8 of set 1 | poum.
# Processing Record 9 of set 1 | juneau.
# Processing Record 10 of set 1 | albany.
# Processing Record 11 of set 1 | nikita.
# Processing Record 12 of set 1 | lavrentiya.
# Processing Record 13 of set 1 | mahebourg.
# Processing Record 14 of set 1 | codrington.
# Processing Record 15 of set 1 | airai.
# Processing Record 16 of set 1 | mount isa.
# Processing Record 17 of set 1 | hermanus.
# Processing Record 18 of set 1 | dikson.
# Processing Record 19 of set 1 | norman wells.
# Processing Record 20 of set 1 | buri.
# Processing Record 21 of set 1 | cape town.
# Processing Record 22 of set 1 | aktau.
# Processing Record 23 of set 1 | tiznit.
# Processing Record 24 of set 1 | yellowknife.
# Processing Record 25 of set 1 | saint-philippe.
# Processing Record 26 of set 1 | riyadh.
# Processing Record 27 of set 1 | caravelas.
# Processing Record 28 of set 1 | mataura.
# Processing Record 29 of set 1 | ostrovnoy.
# Processing Record 30 of set 1 | mar del plata.
# Processing Record 31 of set 1 | peniche.
# Processing Record 32 of set 1 | bluff.
# Processing Record 33 of set 1 | new norfolk.
# Processing Record 34 of set 1 | puerto ayora.
# Processing Record 35 of set 1 | punta arenas.
# Processing Record 36 of set 1 | tiksi.
# Processing Record 37 of set 1 | chernyshevskiy.
# Processing Record 38 of set 1 | key west.
# Processing Record 39 of set 1 | ushuaia.
# Processing Record 40 of set 1 | upernavik.
# Processing Record 41 of set 1 | tecoanapa.
# Processing Record 42 of set 1 | quatre cocos.
# Processing Record 43 of set 1 | isfara.
# Processing Record 44 of set 1 | amapa.
# Processing Record 45 of set 1 | guilin.
# Processing Record 46 of set 1 | san quintin.
# Processing Record 47 of set 1 | arraial do cabo.
# Processing Record 48 of set 1 | lebu.
# Processing Record 49 of set 1 | rikitea.
# Processing Record 50 of set 1 | aktash.
# Missing field/result... skipping.
# Processing Record 1 of set 2 | lakes entrance.
# Processing Record 2 of set 2 | karpathos.
# Processing Record 3 of set 2 | oranjestad.
# Processing Record 4 of set 2 | bredasdorp.
# Processing Record 5 of set 2 | khani.
# Processing Record 6 of set 2 | cidreira.
# Processing Record 7 of set 2 | hami.
# Processing Record 8 of set 2 | salalah.
# Processing Record 9 of set 2 | ahipara.
# Processing Record 10 of set 2 | gatesville.
# Processing Record 11 of set 2 | nome.
# Processing Record 12 of set 2 | sisimiut.
# Processing Record 13 of set 2 | tzaneen.
# Processing Record 14 of set 2 | moron.
# Processing Record 15 of set 2 | huntsville.
# Processing Record 16 of set 2 | kapaa.
# Processing Record 17 of set 2 | kodiak.
# Processing Record 18 of set 2 | nelson bay.
# Processing Record 19 of set 2 | sola.
# Processing Record 20 of set 2 | vestmannaeyjar.
# Processing Record 21 of set 2 | shingu.
# Processing Record 22 of set 2 | vaini.
# Processing Record 23 of set 2 | port alfred.
# Processing Record 24 of set 2 | chibuto.
# Processing Record 25 of set 2 | deputatskiy.
# Processing Record 26 of set 2 | dekar.
# Processing Record 27 of set 2 | chokurdakh.
# Processing Record 28 of set 2 | barrow.
# Processing Record 29 of set 2 | ribeira grande.
# Processing Record 30 of set 2 | la ronge.
# Processing Record 31 of set 2 | te anau.
# Processing Record 32 of set 2 | pisco.
# Processing Record 33 of set 2 | clyde river.
# Processing Record 34 of set 2 | aswan.
# Processing Record 35 of set 2 | hofn.
# Processing Record 36 of set 2 | urusha.
# Processing Record 37 of set 2 | jamestown.
# Processing Record 38 of set 2 | avera.
# Processing Record 39 of set 2 | galesong.
# Processing Record 40 of set 2 | east london.
# Processing Record 41 of set 2 | bandarbeyla.
# Processing Record 42 of set 2 | baicheng.
# Processing Record 43 of set 2 | abapo.
# Processing Record 44 of set 2 | urucara.
# Processing Record 45 of set 2 | myitkyina.
# Processing Record 46 of set 2 | prince rupert.
# Processing Record 47 of set 2 | chuy.
# Processing Record 48 of set 2 | banjar.
# Processing Record 49 of set 2 | alihe.
# Processing Record 50 of set 2 | ballina.
# Processing Record 1 of set 3 | illoqqortoormiut.
# Missing field/result... skipping.
# Processing Record 2 of set 3 | sitka.
# Processing Record 3 of set 3 | bathsheba.
# Processing Record 4 of set 3 | nantucket.
# Processing Record 5 of set 3 | thompson.
# Processing Record 6 of set 3 | port-cartier.
# Processing Record 7 of set 3 | gorodets.
# Processing Record 8 of set 3 | sentyabrskiy.
# Missing field/result... skipping.
# Processing Record 9 of set 3 | sergeyevka.
# Processing Record 10 of set 3 | kapoeta.
# Missing field/result... skipping.
# Processing Record 11 of set 3 | comodoro rivadavia.
# Processing Record 12 of set 3 | hasaki.
# Processing Record 13 of set 3 | sayyan.
# Processing Record 14 of set 3 | sangar.
# Processing Record 15 of set 3 | san pedro buenavista.
# Processing Record 16 of set 3 | port lincoln.
# Processing Record 17 of set 3 | kaspiysk.
# Processing Record 18 of set 3 | saint george.
# Processing Record 19 of set 3 | sal rei.
# Processing Record 20 of set 3 | kathu.
# Processing Record 21 of set 3 | katsuura.
# Processing Record 22 of set 3 | lompoc.
# Processing Record 23 of set 3 | faanui.
# Processing Record 24 of set 3 | souillac.
# Processing Record 25 of set 3 | ca mau.
# Processing Record 26 of set 3 | sagua la grande.
# Processing Record 27 of set 3 | mys shmidta.
# Missing field/result... skipping.
# Processing Record 28 of set 3 | sao filipe.
# Processing Record 29 of set 3 | santiago del estero.
# Processing Record 30 of set 3 | umzimvubu.
# Missing field/result... skipping.
# Processing Record 31 of set 3 | bambanglipuro.
# Processing Record 32 of set 3 | oron.
# Processing Record 33 of set 3 | port hedland.
# Processing Record 34 of set 3 | khatanga.
# Processing Record 35 of set 3 | puerto del rosario.
# Processing Record 36 of set 3 | brooks.
# Processing Record 37 of set 3 | curvelo.
# Processing Record 38 of set 3 | pevek.
# Processing Record 39 of set 3 | hithadhoo.
# Processing Record 40 of set 3 | bethel.
# Processing Record 41 of set 3 | sao joao da barra.
# Processing Record 42 of set 3 | nuqui.
# Processing Record 43 of set 3 | mucurapo.
# Processing Record 44 of set 3 | nalut.
# Processing Record 45 of set 3 | kruisfontein.
# Processing Record 46 of set 3 | sao francisco de assis.
# Missing field/result... skipping.
# Processing Record 47 of set 3 | tsihombe.
# Missing field/result... skipping.
# Processing Record 48 of set 3 | talbahat.
# Processing Record 49 of set 3 | tessalit.
# Processing Record 50 of set 3 | novyy urengoy.
# Processing Record 1 of set 4 | hilo.
# Processing Record 2 of set 4 | ponta delgada.
# Processing Record 3 of set 4 | severo-kurilsk.
# Processing Record 4 of set 4 | torbay.
# Processing Record 5 of set 4 | port elizabeth.
# Processing Record 6 of set 4 | hemet.
# Processing Record 7 of set 4 | qaanaaq.
# Processing Record 8 of set 4 | muros.
# Processing Record 9 of set 4 | luderitz.
# Processing Record 10 of set 4 | kavieng.
# Processing Record 11 of set 4 | baudh.
# Processing Record 12 of set 4 | zyryanka.
# Processing Record 13 of set 4 | placido de castro.
# Processing Record 14 of set 4 | qeshm.
# Processing Record 15 of set 4 | alice springs.
# Processing Record 16 of set 4 | puerto cabello.
# Processing Record 17 of set 4 | palabuhanratu.
# Missing field/result... skipping.
# Processing Record 18 of set 4 | pathein.
# Processing Record 19 of set 4 | maldonado.
# Processing Record 20 of set 4 | zhigansk.
# Processing Record 21 of set 4 | sambava.
# Processing Record 22 of set 4 | uchaly.
# Processing Record 23 of set 4 | haines junction.
# Processing Record 24 of set 4 | padang.
# Processing Record 25 of set 4 | georgetown.
# Processing Record 26 of set 4 | saldanha.
# Processing Record 27 of set 4 | cabo san lucas.
# Processing Record 28 of set 4 | nikolskoye.
# Processing Record 29 of set 4 | noumea.
# Processing Record 30 of set 4 | akureyri.
# Processing Record 31 of set 4 | saint-pierre.
# Processing Record 32 of set 4 | dali.
# Processing Record 33 of set 4 | castro.
# Processing Record 34 of set 4 | fort nelson.
# Processing Record 35 of set 4 | baykit.
# Processing Record 36 of set 4 | chikoy.
# Missing field/result... skipping.
# Processing Record 37 of set 4 | flin flon.
# Processing Record 38 of set 4 | carnarvon.
# Processing Record 39 of set 4 | sept-iles.
# Processing Record 40 of set 4 | pyaozerskiy.
# Processing Record 41 of set 4 | san andres.
# Processing Record 42 of set 4 | urengoy.
# Processing Record 43 of set 4 | provideniya.
# Processing Record 44 of set 4 | hihifo.
# Missing field/result... skipping.
# Processing Record 45 of set 4 | ponta do sol.
# Processing Record 46 of set 4 | monte gordo.
# Processing Record 47 of set 4 | gweta.
# Processing Record 48 of set 4 | along.
# Processing Record 49 of set 4 | alofi.
# Processing Record 50 of set 4 | rovaniemi.
# Processing Record 1 of set 5 | taoudenni.
# Processing Record 2 of set 5 | ihosy.
# Processing Record 3 of set 5 | longyearbyen.
# Processing Record 4 of set 5 | bac lieu.
# Missing field/result... skipping.
# Processing Record 5 of set 5 | galveston.
# Processing Record 6 of set 5 | muhos.
# Processing Record 7 of set 5 | fort saint james.
# Processing Record 8 of set 5 | camocim.
# Processing Record 9 of set 5 | mentok.
# Missing field/result... skipping.
# Processing Record 10 of set 5 | saleaula.
# Missing field/result... skipping.
# Processing Record 11 of set 5 | gerash.
# Processing Record 12 of set 5 | atuona.
# Processing Record 13 of set 5 | maragogi.
# Processing Record 14 of set 5 | sulangan.
# Processing Record 15 of set 5 | san onofre.
# Processing Record 16 of set 5 | jiwani.
# Processing Record 17 of set 5 | contai.
# Processing Record 18 of set 5 | ixtapa.
# Processing Record 19 of set 5 | kungurtug.
# Processing Record 20 of set 5 | camabatela.
# Processing Record 21 of set 5 | bridgetown.
# Processing Record 22 of set 5 | tasiilaq.
# Processing Record 23 of set 5 | qom.
# Processing Record 24 of set 5 | belushya guba.
# Missing field/result... skipping.
# Processing Record 25 of set 5 | abong mbang.
# Processing Record 26 of set 5 | samusu.
# Missing field/result... skipping.
# Processing Record 27 of set 5 | turukhansk.
# Processing Record 28 of set 5 | eidsvag.
# Processing Record 29 of set 5 | tura.
# Processing Record 30 of set 5 | sarakhs.
# Processing Record 31 of set 5 | lerik.
# Processing Record 32 of set 5 | taga dzong.
# Missing field/result... skipping.
# Processing Record 33 of set 5 | toliary.
# Missing field/result... skipping.
# Processing Record 34 of set 5 | ipixuna.
# Processing Record 35 of set 5 | san patricio.
# Processing Record 36 of set 5 | giulianova.
# Processing Record 37 of set 5 | amiens.
# Processing Record 38 of set 5 | nuuk.
# Processing Record 39 of set 5 | shunyi.
# Processing Record 40 of set 5 | puerto escondido.
# Processing Record 41 of set 5 | paracuru.
# Processing Record 42 of set 5 | saint-denis.
# Processing Record 43 of set 5 | nikolayevka.
# Processing Record 44 of set 5 | viedma.
# Processing Record 45 of set 5 | mercedes.
# Processing Record 46 of set 5 | hoquiam.
# Processing Record 47 of set 5 | sumter.
# Processing Record 48 of set 5 | naze.
# Processing Record 49 of set 5 | aranda de duero.
# Processing Record 50 of set 5 | lakhimpur.
# Processing Record 1 of set 6 | mecca.
# Processing Record 2 of set 6 | faya.
# Processing Record 3 of set 6 | novaya lyada.
# Processing Record 4 of set 6 | fortuna foothills.
# Processing Record 5 of set 6 | balikpapan.
# Processing Record 6 of set 6 | pokhara.
# Processing Record 7 of set 6 | grand baie.
# Processing Record 8 of set 6 | lata.
# Processing Record 9 of set 6 | san cristobal.
# Processing Record 10 of set 6 | palmer.
# Processing Record 11 of set 6 | jarjis.
# Missing field/result... skipping.
# Processing Record 12 of set 6 | barentsburg.
# Missing field/result... skipping.
# Processing Record 13 of set 6 | vila velha.
# Processing Record 14 of set 6 | cherskiy.
# Processing Record 15 of set 6 | hudson bay.
# Processing Record 16 of set 6 | hay river.
# Processing Record 17 of set 6 | san policarpo.
# Processing Record 18 of set 6 | sebring.
# Processing Record 19 of set 6 | mount gambier.
# Processing Record 20 of set 6 | nanortalik.
# Processing Record 21 of set 6 | sarretudvari.
# Processing Record 22 of set 6 | sistranda.
# Processing Record 23 of set 6 | cradock.
# Processing Record 24 of set 6 | nizhneyansk.
# Missing field/result... skipping.
# Processing Record 25 of set 6 | seoul.
# Processing Record 26 of set 6 | amderma.
# Missing field/result... skipping.
# Processing Record 27 of set 6 | uzhur.
# Processing Record 28 of set 6 | maniitsoq.
# Processing Record 29 of set 6 | talikota.
# Processing Record 30 of set 6 | takab.
# Processing Record 31 of set 6 | klaksvik.
# Processing Record 32 of set 6 | kaitangata.
# Processing Record 33 of set 6 | honiara.
# Processing Record 34 of set 6 | tuktoyaktuk.
# Processing Record 35 of set 6 | killybegs.
# Processing Record 36 of set 6 | zonguldak.
# Processing Record 37 of set 6 | isangel.
# Processing Record 38 of set 6 | nyimba.
# Processing Record 39 of set 6 | thunder bay.
# Processing Record 40 of set 6 | shitkino.
# Processing Record 41 of set 6 | gat.
# Processing Record 42 of set 6 | port blair.
# Processing Record 43 of set 6 | bereda.
# Processing Record 44 of set 6 | kavaratti.
# Processing Record 45 of set 6 | mabaruma.
# Processing Record 46 of set 6 | verkhniy uslon.
# Processing Record 47 of set 6 | port shepstone.
# Processing Record 48 of set 6 | ouallam.
# Processing Record 49 of set 6 | zeya.
# Processing Record 50 of set 6 | nabire.
# Processing Record 1 of set 7 | kaeo.
# Processing Record 2 of set 7 | kamenka.
# Processing Record 3 of set 7 | rocha.
# Processing Record 4 of set 7 | lagoa.
# Processing Record 5 of set 7 | abu samrah.
# Processing Record 6 of set 7 | licata.
# Processing Record 7 of set 7 | shenjiamen.
# Processing Record 8 of set 7 | wladyslawowo.
# Processing Record 9 of set 7 | tambura.
# Missing field/result... skipping.
# Processing Record 10 of set 7 | evensk.
# Processing Record 11 of set 7 | tommot.
# Processing Record 12 of set 7 | wattegama.
# Processing Record 13 of set 7 | araci.
# Processing Record 14 of set 7 | ancud.
# Processing Record 15 of set 7 | muravlenko.
# Processing Record 16 of set 7 | ayr.
# Processing Record 17 of set 7 | galiwinku.
# Missing field/result... skipping.
# Processing Record 18 of set 7 | vaitupu.
# Missing field/result... skipping.
# Processing Record 19 of set 7 | alekseyevka.
# Processing Record 20 of set 7 | talnakh.
# Processing Record 21 of set 7 | mackenzie.
# Processing Record 22 of set 7 | martin.
# Processing Record 23 of set 7 | znamenskoye.
# Processing Record 24 of set 7 | gazanjyk.
# Processing Record 25 of set 7 | kahului.
# Processing Record 26 of set 7 | emba.
# Processing Record 27 of set 7 | saskylakh.
# Processing Record 28 of set 7 | la gaulette.
# Missing field/result... skipping.
# Processing Record 29 of set 7 | elko.
# Processing Record 30 of set 7 | tigil.
# Processing Record 31 of set 7 | marsh harbour.
# Processing Record 32 of set 7 | severo-yeniseyskiy.
# Processing Record 33 of set 7 | vao.
# Processing Record 34 of set 7 | luwuk.
# Processing Record 35 of set 7 | thomaston.
# Processing Record 36 of set 7 | doctor arroyo.
# Processing Record 37 of set 7 | campo verde.
# Processing Record 38 of set 7 | aykhal.
# Processing Record 39 of set 7 | constitucion.
# Processing Record 40 of set 7 | komsomolskiy.
# Processing Record 41 of set 7 | marystown.
# Processing Record 42 of set 7 | salym.
# Processing Record 43 of set 7 | payakumbuh.
# Processing Record 44 of set 7 | krasnoselkup.
# Missing field/result... skipping.
# Processing Record 45 of set 7 | richards bay.
# Processing Record 46 of set 7 | guerrero negro.
# Processing Record 47 of set 7 | belmonte.
# Processing Record 48 of set 7 | troitskoye.
# Processing Record 49 of set 7 | bambous virieux.
# Processing Record 50 of set 7 | vostok.
# Processing Record 1 of set 8 | bilibino.
# Processing Record 2 of set 8 | mao.
# Processing Record 3 of set 8 | kawalu.
# Processing Record 4 of set 8 | marawi.
# Processing Record 5 of set 8 | huarmey.
# Processing Record 6 of set 8 | kisangani.
# Processing Record 7 of set 8 | pahrump.
# Processing Record 8 of set 8 | kismayo.
# Missing field/result... skipping.
# Processing Record 9 of set 8 | finnsnes.
# Processing Record 10 of set 8 | mosetse.
# Processing Record 11 of set 8 | harper.
# Processing Record 12 of set 8 | sri aman.
# Processing Record 13 of set 8 | asau.
# Missing field/result... skipping.
# Processing Record 14 of set 8 | dieppe.
# Processing Record 15 of set 8 | acapulco.
# Processing Record 16 of set 8 | sioux lookout.
# Processing Record 17 of set 8 | porto murtinho.
# Processing Record 18 of set 8 | abu kamal.
# Processing Record 19 of set 8 | maungatapere.
# Processing Record 20 of set 8 | omsukchan.
# Processing Record 21 of set 8 | gambela.
# Processing Record 22 of set 8 | sault sainte marie.
# Processing Record 23 of set 8 | preobrazheniye.
# Processing Record 24 of set 8 | yakeshi.
# Processing Record 25 of set 8 | dingle.
# Processing Record 26 of set 8 | stockach.
# Processing Record 27 of set 8 | saryg-sep.
# Processing Record 28 of set 8 | vieux-habitants.
# Processing Record 29 of set 8 | beboto.
# Processing Record 30 of set 8 | benicarlo.
# Processing Record 31 of set 8 | egvekinot.
# Processing Record 32 of set 8 | bonga.
# Processing Record 33 of set 8 | konevo.
# Processing Record 34 of set 8 | hambantota.
# Processing Record 35 of set 8 | luang prabang.
# Processing Record 36 of set 8 | tumannyy.
# Missing field/result... skipping.
# Processing Record 37 of set 8 | kamaishi.
# Processing Record 38 of set 8 | chitral.
# Processing Record 39 of set 8 | tautira.
# Processing Record 40 of set 8 | vohibinany.
# Processing Record 41 of set 8 | aklavik.
# Processing Record 42 of set 8 | paamiut.
# Processing Record 43 of set 8 | san miguel.
# Processing Record 44 of set 8 | bengkulu.
# Missing field/result... skipping.
# Processing Record 45 of set 8 | barcelos.
# Processing Record 46 of set 8 | geraldton.
# Processing Record 47 of set 8 | hailar.
# Processing Record 48 of set 8 | ahuimanu.
# Processing Record 49 of set 8 | ust-kuyga.
# Processing Record 50 of set 8 | margate.
# Processing Record 1 of set 9 | avarua.
# Processing Record 2 of set 9 | okhotsk.
# Processing Record 3 of set 9 | mufulira.
# Processing Record 4 of set 9 | blythe.
# Processing Record 5 of set 9 | caceres.
# Processing Record 6 of set 9 | saint anthony.
# Processing Record 7 of set 9 | grand river south east.
# Missing field/result... skipping.
# Processing Record 8 of set 9 | nargana.
# Processing Record 9 of set 9 | buckeye.
# Processing Record 10 of set 9 | kokoda.
# Processing Record 11 of set 9 | tuatapere.
# Processing Record 12 of set 9 | esperance.
# Processing Record 13 of set 9 | ngunguru.
# Processing Record 14 of set 9 | santa flavia.
# Processing Record 15 of set 9 | attawapiskat.
# Missing field/result... skipping.
# Processing Record 16 of set 9 | antofagasta.
# Processing Record 17 of set 9 | pacific grove.
# Processing Record 18 of set 9 | tambacounda.
# Processing Record 19 of set 9 | port hardy.
# Processing Record 20 of set 9 | pimentel.
# Processing Record 21 of set 9 | igarka.
# Processing Record 22 of set 9 | hanyang.
# Processing Record 23 of set 9 | barbacena.
# Processing Record 24 of set 9 | novo aripuana.
# Processing Record 25 of set 9 | daru.
# Processing Record 26 of set 9 | ariquemes.
# Processing Record 27 of set 9 | kuala terengganu.
# Processing Record 28 of set 9 | guaraniacu.
# Processing Record 29 of set 9 | mirabad.
# Processing Record 30 of set 9 | benalla.
# Processing Record 31 of set 9 | vila franca do campo.
# Processing Record 32 of set 9 | shimoda.
# Processing Record 33 of set 9 | camacha.
# Processing Record 34 of set 9 | laguna.
# Processing Record 35 of set 9 | paraiso.
# Processing Record 36 of set 9 | narsaq.
# Processing Record 37 of set 9 | mitsamiouli.
# Processing Record 38 of set 9 | sibolga.
# Processing Record 39 of set 9 | dutse.
# Processing Record 40 of set 9 | robe.
# Processing Record 41 of set 9 | champerico.
# Processing Record 42 of set 9 | utiroa.
# Missing field/result... skipping.
# Processing Record 43 of set 9 | jiuquan.
# Processing Record 44 of set 9 | fuerte olimpo.
# Processing Record 45 of set 9 | antalaha.
# Processing Record 46 of set 9 | dvinskoy.
# Processing Record 47 of set 9 | mehamn.
# Processing Record 48 of set 9 | ouesso.
# Processing Record 49 of set 9 | xining.
# Processing Record 50 of set 9 | vanavara.
# Processing Record 1 of set 10 | gengenbach.
# Processing Record 2 of set 10 | ramsgate.
# Processing Record 3 of set 10 | louisbourg.
# Missing field/result... skipping.
# Processing Record 4 of set 10 | asosa.
# Processing Record 5 of set 10 | innisfail.
# Processing Record 6 of set 10 | melbu.
# Processing Record 7 of set 10 | puri.
# Processing Record 8 of set 10 | yanam.
# Processing Record 9 of set 10 | mponela.
# Processing Record 10 of set 10 | makakilo city.
# Processing Record 11 of set 10 | coahuayana.
# Processing Record 12 of set 10 | chimbote.
# Processing Record 13 of set 10 | bria.
# Processing Record 14 of set 10 | husavik.
# Processing Record 15 of set 10 | roald.
# Processing Record 16 of set 10 | great falls.
# Processing Record 17 of set 10 | mareeba.
# Processing Record 18 of set 10 | mayo.
# Processing Record 19 of set 10 | lubango.
# Processing Record 20 of set 10 | belyy yar.
# Processing Record 21 of set 10 | pitimbu.
# Processing Record 22 of set 10 | iquitos.
# Processing Record 23 of set 10 | grand gaube.
# Processing Record 24 of set 10 | norrtalje.
# Processing Record 25 of set 10 | vila.
# Processing Record 26 of set 10 | tallahassee.
# Processing Record 27 of set 10 | cap malheureux.
# Processing Record 28 of set 10 | lorengau.
# Processing Record 29 of set 10 | havre-saint-pierre.
# Processing Record 30 of set 10 | thinadhoo.
# Processing Record 31 of set 10 | mogadishu.
# Processing Record 32 of set 10 | srednekolymsk.
# Processing Record 33 of set 10 | touros.
# Processing Record 34 of set 10 | biaora.
# Processing Record 35 of set 10 | shu.
# Processing Record 36 of set 10 | kolaras.
# Processing Record 37 of set 10 | boa vista.
# Processing Record 38 of set 10 | marfino.
# Processing Record 39 of set 10 | port hawkesbury.
# Processing Record 40 of set 10 | ambunti.
# Processing Record 41 of set 10 | acucena.
# Processing Record 42 of set 10 | yuksekova.
# Processing Record 43 of set 10 | rawson.
# Processing Record 44 of set 10 | ilo.
# Processing Record 45 of set 10 | najran.
# Processing Record 46 of set 10 | skjervoy.
# Processing Record 47 of set 10 | ambilobe.
# Processing Record 48 of set 10 | verkhnyaya inta.
# Processing Record 49 of set 10 | the valley.
# Processing Record 50 of set 10 | santa teresa.
# Processing Record 1 of set 11 | ponorogo.
# Processing Record 2 of set 11 | sao fidelis.
# Processing Record 3 of set 11 | idritsa.
# Processing Record 4 of set 11 | baraboo.
# Processing Record 5 of set 11 | kaka.
# Processing Record 6 of set 11 | karak.
# Processing Record 7 of set 11 | longwy.
# Processing Record 8 of set 11 | amargosa.
# Processing Record 9 of set 11 | yushu.
# Processing Record 10 of set 11 | ivdel.
# Processing Record 11 of set 11 | xiaoweizhai.
# Processing Record 12 of set 11 | khandbari.
# Processing Record 13 of set 11 | yarensk.
# Processing Record 14 of set 11 | rorvik.
# Processing Record 15 of set 11 | falun.
# Processing Record 16 of set 11 | garowe.
# Processing Record 17 of set 11 | collie.
# Processing Record 18 of set 11 | jasper.
# Processing Record 19 of set 11 | zima.
# Processing Record 20 of set 11 | dunedin.
# Processing Record 21 of set 11 | rawah.
# Missing field/result... skipping.
# Processing Record 22 of set 11 | ozernovskiy.
# Processing Record 23 of set 11 | ust-nera.
# Processing Record 24 of set 11 | tazovskiy.
# Processing Record 25 of set 11 | gizo.
# Processing Record 26 of set 11 | nhulunbuy.
# Processing Record 27 of set 11 | makarov.
# Processing Record 28 of set 11 | fortuna.
# Processing Record 29 of set 11 | oktyabrskoye.
# Processing Record 30 of set 11 | wasilla.
# Processing Record 31 of set 11 | chara.
# Processing Record 32 of set 11 | tadine.
# Processing Record 33 of set 11 | flinders.
# Processing Record 34 of set 11 | bethanien.
# Processing Record 35 of set 11 | dehloran.
# Processing Record 36 of set 11 | el tarra.
# Processing Record 37 of set 11 | coos bay.
# Processing Record 38 of set 11 | changping.
# Processing Record 39 of set 11 | palauig.
# Processing Record 40 of set 11 | beyneu.
# Processing Record 41 of set 11 | aksu.
# Processing Record 42 of set 11 | araguacu.
# Missing field/result... skipping.
# Processing Record 43 of set 11 | mendahara.
# Missing field/result... skipping.
# Processing Record 44 of set 11 | asfi.
# Missing field/result... skipping.
# Processing Record 45 of set 11 | viransehir.
# Processing Record 46 of set 11 | iqaluit.
# Processing Record 47 of set 11 | shiyan.
# Processing Record 48 of set 11 | eyl.
# Processing Record 49 of set 11 | malakisi.
# Missing field/result... skipping.
# Processing Record 50 of set 11 | pobe.
# Processing Record 1 of set 12 | varkaus.
# Processing Record 2 of set 12 | iranshahr.
# Processing Record 3 of set 12 | bobo dioulasso.
# Missing field/result... skipping.
# Processing Record 4 of set 12 | berlevag.
# Processing Record 5 of set 12 | konosha.
# Processing Record 6 of set 12 | turtas.
# Processing Record 7 of set 12 | chagda.
# Missing field/result... skipping.
# Processing Record 8 of set 12 | mwinilunga.
# Processing Record 9 of set 12 | meyungs.
# Missing field/result... skipping.
# Processing Record 10 of set 12 | hoa binh.
# Processing Record 11 of set 12 | kousseri.
# Missing field/result... skipping.
# Processing Record 12 of set 12 | erzin.
# Processing Record 13 of set 12 | steubenville.
# Processing Record 14 of set 12 | coria.
# Processing Record 15 of set 12 | goundam.
# Processing Record 16 of set 12 | ambovombe.
# Processing Record 17 of set 12 | port moresby.
# Processing Record 18 of set 12 | vilhena.
# Processing Record 19 of set 12 | kozlovka.
# Processing Record 20 of set 12 | biskupiec.
# Processing Record 21 of set 12 | anuchino.
# Processing Record 22 of set 12 | crib point.
# Processing Record 23 of set 12 | sorong.
# Processing Record 24 of set 12 | nogliki.
# Processing Record 25 of set 12 | general jose eduvigis diaz.
# Processing Record 26 of set 12 | namibe.
# Processing Record 27 of set 12 | gatton.
# Processing Record 28 of set 12 | tual.
# Processing Record 29 of set 12 | puerto leguizamo.
# Processing Record 30 of set 12 | champoton.
# Processing Record 31 of set 12 | bairnsdale.
# Processing Record 32 of set 12 | aripuana.
# Processing Record 33 of set 12 | los llanos de aridane.
# Processing Record 34 of set 12 | takahashi.
# Processing Record 35 of set 12 | kailua.
# Processing Record 36 of set 12 | shelburne.
# Processing Record 37 of set 12 | solnechnyy.
# Processing Record 38 of set 12 | yorkton.
# Processing Record 39 of set 12 | san carlos.
# Processing Record 40 of set 12 | mrirt.
# Missing field/result... skipping.
# Processing Record 41 of set 12 | dafeng.
# Processing Record 42 of set 12 | pamekasan.
# Processing Record 43 of set 12 | viligili.
# Missing field/result... skipping.
# Processing Record 44 of set 12 | oussouye.
# Processing Record 45 of set 12 | hamilton.
# Processing Record 46 of set 12 | chapais.
# Processing Record 47 of set 12 | bardiyah.
# Missing field/result... skipping.
# Processing Record 48 of set 12 | bouna.
# Processing Record 49 of set 12 | soderhamn.
# Processing Record 50 of set 12 | president roxas.
# Processing Record 1 of set 13 | demba.
# Processing Record 2 of set 13 | patan.
# Processing Record 3 of set 13 | shakhunya.
# Processing Record 4 of set 13 | wa.
# Missing field/result... skipping.
# Processing Record 5 of set 13 | bure.
# Processing Record 6 of set 13 | carire.
# Processing Record 7 of set 13 | barawe.
# Missing field/result... skipping.
# Processing Record 8 of set 13 | adrar.
# Processing Record 9 of set 13 | sann.
# Processing Record 10 of set 13 | port macquarie.
# Processing Record 11 of set 13 | arua.
# Processing Record 12 of set 13 | coihaique.
# Processing Record 13 of set 13 | warqla.
# Missing field/result... skipping.
# Processing Record 14 of set 13 | puerto baquerizo moreno.
# Processing Record 15 of set 13 | soma.
# Processing Record 16 of set 13 | leningradskiy.
# Processing Record 17 of set 13 | wanning.
# Processing Record 18 of set 13 | saint-francois.
# Processing Record 19 of set 13 | araguatins.
# Missing field/result... skipping.
# Processing Record 20 of set 13 | saint-augustin.
# Processing Record 21 of set 13 | olafsvik.
# Missing field/result... skipping.
# Processing Record 22 of set 13 | port ellen.
# Missing field/result... skipping.
# Processing Record 23 of set 13 | thanh hoa.
# Processing Record 24 of set 13 | terekli-mekteb.
# Processing Record 25 of set 13 | santa marta.
# Processing Record 26 of set 13 | camacupa.
# Processing Record 27 of set 13 | ulaangom.
# Processing Record 28 of set 13 | port-gentil.
# Processing Record 29 of set 13 | ketchikan.
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
#
# * Display the DataFrame

# %%
#Converting to dataframe
weather_df = pd.DataFrame({
    "City":city_list,
    "Cloudiness":cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Lon":lon,
    "Max Temp":max_temp,
    "Wind Speed":wind_speed
})

#Printing Counts
weather_df.count()
# Out:
# City          575
# Cloudiness    575
# Country       575
# Date          575
# Humidity      575
# Lat           575
# Lon           575
# Max Temp      575
# Wind Speed    575
# dtype: int64

# %%
weather_df.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0      hobart          99      AU  1573151129        75 -42.88  147.33
# 1   fairbanks          90      US  1573151180       100  64.84 -147.72
# 2  butaritari          47      KI  1573151189        71   3.07  172.79
# 3   busselton           0      AU  1573151189        54 -33.64  115.35
# 4    victoria          90      BN  1573151190        88   5.28  115.24
#
#    Max Temp  Wind Speed
# 0     42.80        8.05
# 1     24.80        5.86
# 2     83.71        9.06
# 3     55.00       14.83
# 4     78.80        3.36

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Plot Titles (with date of analysis) and Axes Labels.
fig, ax = plt.subplots()
plt.scatter(x=lat, y=max_temp, marker = "o", color="DarkBlue", alpha=0.5)
plt.title(f"City Latitude vs. Max Temp {today}")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
ax.grid()
plt.savefig('City Latitude vs. Max Temp.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Plot Titles (with date of analysis) and Axes Labels.
fig, ax = plt.subplots()
plt.scatter(x=lat, y=humidity, marker = "o", color="DarkBlue", alpha=0.5)
plt.title(f'City Latitude vs. Humidity {today}')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid = True
ax.grid()
plt.savefig('City Latitude vs. Humidity.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Plot Titles (with date of analysis) and Axes Labels.
fig, ax = plt.subplots()
plt.scatter(x=lat, y=cloudiness, marker = "o", color="DarkBlue", alpha=0.5)
plt.title(f'City Latitude vs. Cloudiness {today}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid = True
ax.grid()
plt.savefig('City Latitude vs. Cloudiness.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Plot Titles (with date of analysis) and Axes Labels.
fig, ax = plt.subplots()
plt.scatter(x=lat, y=wind_speed, marker = "o", color="DarkBlue", alpha=0.5)
plt.title(f'City Latitude vs. Wind Speed {today}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.grid = True
ax.grid()
plt.savefig('City Latitude vs. Wind Speed.png')
plt.show()
